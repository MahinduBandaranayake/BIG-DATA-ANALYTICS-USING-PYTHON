# %%
#Importing the pandas library

import pandas as pd

# %%
#Importing the csv data file 
DataAnalytics= pd.read_csv(r'C:\Users\USER\Documents\PUSL3121 Big Data Analytics (22SPM)\archive\Bengaluru_House_Data.csv')
DataAnalytics.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
#Number of Rows and Columns in the dataset
DataAnalytics.shape
# Out:
# (13320, 9)

# %%
#Checking whether Null values are present
DataAnalytics.isnull()
# Out:
#        area_type  availability  location   size  society  total_sqft   bath  \
# 0          False         False     False  False    False       False  False
# 1          False         False     False  False    False       False  False
# 2          False         False     False  False     True       False  False
# 3          False         False     False  False    False       False  False
# 4          False         False     False  False     True       False  False
# ...          ...           ...       ...    ...      ...         ...    ...
# 13315      False         False     False  False    False       False  False
# 13316      False         False     False  False     True       False  False
# 13317      False         False     False  False    False       False  False
# 13318      False         False     False  False    False       False  False
# 13319      False         False     False  False     True       False  False
#
#        balcony  price
# 0        False  False
# ...

# %%
#Identifying the number of Null values for each columns
DataAnalytics.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
#Displaying exactly the total number of Null Values
DataAnalytics.isnull().sum().sum()
# Out:
# 6201

# %% [markdown]
# ## FOUR WAYS OF PROVIDING  SOLUTIONS TO NULL VALUES
#
# #Filling Null Values
#
# #Interpolation
#
# #Replacing
#
# #Dropping

# %% [markdown]
# # Filling Null Values

# %%
# Filling Null values can be done in several ways
#1. Filling with the Previous Value(Vertically)

DataAnalytics1=DataAnalytics.fillna(method='pad')
DataAnalytics1
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
#2. Filling with the Next  Value(Vertically)

DataAnalytics2=DataAnalytics.fillna(method='bfill')
DataAnalytics2
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
#3. Filling values with the previous(Horizontally)

DataAnalytics3=DataAnalytics.fillna(method='pad',axis=1)
DataAnalytics3
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft bath balcony  price
# 0          2 BHK  Coomee        1056  2.0     1.0  39.07
# ...

# %%
#4. Filling Values with the Next Value(Horizontally)

DataAnalytics4=DataAnalytics.fillna(method='bfill', axis=1)
DataAnalytics4
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft bath balcony  price
# 0          2 BHK  Coomee        1056  2.0     1.0  39.07
# ...

# %%
#5. Filling different values (For a specific row)

DataAnalytics5=DataAnalytics.fillna({'society':'Selware','balcony':'30'})
DataAnalytics5
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath balcony   price
# 0          2 BHK  Coomee        1056   2.0     1.0   39.07
# ...

# %% [markdown]
# # Interpolation

# %%
#1. Identifying and filling according to the pattern of the above and below values in the column or row

DataAnalytics['balcony']=DataAnalytics['balcony'].interpolate(method='linear')
DataAnalytics
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
#2. Interpolating, when two or more consective null values are present in the dataset

DataAnalytics['balcony']=DataAnalytics['balcony'].interpolate(method='linear',limit_direction='forward')
DataAnalytics
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %% [markdown]
# # Replacing

# %%
#Importing the numpy library

import numpy as np

# %%
#Replacing the null values by defining the parameters

DataAnalytics6=DataAnalytics.replace(to_replace=np.nan, value=1290)
DataAnalytics6

#Necessary and Relevant values can be assigned using this technique to fill out null values
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %% [markdown]
# # Dropping

# %%
#Out of the all the ways dropping null values can be considered as the efficient way, since the other ways would require a 
#lot of time to check and rectify the total values dataset

# %%
import pandas as pd
DataAnalytics= pd.read_csv(r'C:\Users\USER\Documents\PUSL3121 Big Data Analytics (22SPM)\archive\Bengaluru_House_Data.csv')

# %%
#Therefore to recheck the available number of outlier, the previous equation can be used
DataAnalytics.isnull().sum().sum()
# Out:
# 6201

# %%
#In order to drop those outliers following equation can be used
DataAnalytics7=DataAnalytics.dropna()
DataAnalytics7
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 5      Super built-up  Area  Ready To Move                Whitefield
# 11               Plot  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 13313  Super built-up  Area  Ready To Move               Uttarahalli
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
#As clearly seen, the number of columns have drastically dropped to confirm the fact that outliers
#have been removed from the dataset
#as per the final step the above 
#mentioned equation can be re-run to check the number of outliers in the dataset and
#it can be clarified with the receiving value equals to zero

# %%
DataAnalytics7.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Identifying Outliers in the Dataset

# %%
#There 3 ways of identifying an outlier in a dataset
#1. Z-score method
#2. Percentile method
#3. Interquatile range method

#out of which the 'Z-score' method will be discussed below

# %% [markdown]
# # Z-Score Method

# %%
#First step is to identify whether there are any outliers in particular rows or columns in the dataset
#by using plotting the distplot diagram

# %%
#Out of the available columns,total_sqft will be considered as the particular column to be evaluated

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Checking for Outliers
sns.histplot(DataAnalytics7['price'])
# Out:
# <AxesSubplot: xlabel='price', ylabel='Count'>

# %%
#Seems like there arent any outliers in that particular column.

# %%
#Checking for outliers in another column (to identify it more clearly)
sns.boxplot(DataAnalytics7['bath'])
# Out:
# <AxesSubplot: >

# %%
#It is clearly seen that outliers are present in the dataset by the
#above plot, as point are situated outside the margins

# %%
#Defining the limits

upper_limit=DataAnalytics7['bath'].mean()+3*DataAnalytics7['bath'].std()
lower_limit=DataAnalytics7['bath'].mean()-3*DataAnalytics7['bath'].std()

print ('upper limit',upper_limit)
print ('lower limit',lower_limit)
# Out:
# upper limit 5.101761043765876
# lower limit -0.18500544077761516

# %%
#Finding the outliers

DataAnalytics7.loc[(DataAnalytics7['bath']>upper_limit) | (DataAnalytics7['bath']<lower_limit)]
# Out:
#                   area_type   availability           location       size  \
# 337    Super built-up  Area  Ready To Move     Thigalarapalya      4 BHK
# 459    Super built-up  Area  Ready To Move       1 Giri Nagar     11 BHK
# 490    Super built-up  Area  Ready To Move    Old Madras Road      5 BHK
# 524    Super built-up  Area         17-Dec             Jakkur      4 BHK
# 538    Super built-up  Area  Ready To Move        Mico Layout      9 BHK
# ...                     ...            ...                ...        ...
# 13092  Super built-up  Area  Ready To Move             Hebbal      4 BHK
# 13095  Super built-up  Area  Ready To Move  Sathya Sai Layout      4 BHK
# 13119            Plot  Area  Ready To Move  Sathya Sai Layout  4 Bedroom
# 13180  Super built-up  Area  Ready To Move      Sarakki Nagar      4 BHK
# 13208  Super built-up  Area  Ready To Move             Hebbal      4 BHK
#
#        society total_sqft  bath  balcony  price
# ...

# %%
#There are two possible ways of getting rid of outliers

#1. Trimming
#2. Capping

# %%
#The trimming process will be discussed below (The outliers will be removed from the dataset)

# %%
import pandas as pd
DataAnalytics= pd.read_csv(r'C:\Users\USER\Documents\PUSL3121 Big Data Analytics (22SPM)\archive\Bengaluru_House_Data.csv')
DataAnalytics7=DataAnalytics.dropna()
upper_limit=DataAnalytics7['bath'].mean()+3*DataAnalytics7['bath'].std()
lower_limit=DataAnalytics7['bath'].mean()-3*DataAnalytics7['bath'].std()

print ('upper limit',upper_limit)
print ('lower limit',lower_limit)
DataAnalytics7.loc[(DataAnalytics7['bath']>upper_limit) | (DataAnalytics7['bath']<lower_limit)]
# Out:
# upper limit 5.101761043765876
# lower limit -0.18500544077761516
#                   area_type   availability           location       size  \
# 337    Super built-up  Area  Ready To Move     Thigalarapalya      4 BHK
# 459    Super built-up  Area  Ready To Move       1 Giri Nagar     11 BHK
# 490    Super built-up  Area  Ready To Move    Old Madras Road      5 BHK
# 524    Super built-up  Area         17-Dec             Jakkur      4 BHK
# 538    Super built-up  Area  Ready To Move        Mico Layout      9 BHK
# ...                     ...            ...                ...        ...
# 13092  Super built-up  Area  Ready To Move             Hebbal      4 BHK
# 13095  Super built-up  Area  Ready To Move  Sathya Sai Layout      4 BHK
# 13119            Plot  Area  Ready To Move  Sathya Sai Layout  4 Bedroom
# 13180  Super built-up  Area  Ready To Move      Sarakki Nagar      4 BHK
# 13208  Super built-up  Area  Ready To Move             Hebbal      4 BHK
#
# ...

# %%
#Calculating the total number of outliers

New_DataAnalytics=DataAnalytics7.loc[(DataAnalytics7['bath']>upper_limit) | (DataAnalytics7['bath']<lower_limit)]

print('Previous Data Before Removing Outliers:', len(DataAnalytics7))
print('New Data After Removing Outliers:',len(New_DataAnalytics))
# Out:
# Previous Data: 7496
# New Data: 80

# %%
#Therefore the total will be

print('No of outliers:',len(DataAnalytics7)-len(New_DataAnalytics))
# Out:
# No of outliers: 7416

# %%
#So the dataset is cleaned and ready to be used

New_DataAnalytics
# Out:
#                   area_type   availability           location       size  \
# 337    Super built-up  Area  Ready To Move     Thigalarapalya      4 BHK
# 459    Super built-up  Area  Ready To Move       1 Giri Nagar     11 BHK
# 490    Super built-up  Area  Ready To Move    Old Madras Road      5 BHK
# 524    Super built-up  Area         17-Dec             Jakkur      4 BHK
# 538    Super built-up  Area  Ready To Move        Mico Layout      9 BHK
# ...                     ...            ...                ...        ...
# 13092  Super built-up  Area  Ready To Move             Hebbal      4 BHK
# 13095  Super built-up  Area  Ready To Move  Sathya Sai Layout      4 BHK
# 13119            Plot  Area  Ready To Move  Sathya Sai Layout  4 Bedroom
# 13180  Super built-up  Area  Ready To Move      Sarakki Nagar      4 BHK
# 13208  Super built-up  Area  Ready To Move             Hebbal      4 BHK
#
#        society total_sqft  bath  balcony  price
# ...
